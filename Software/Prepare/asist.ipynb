# %%
import matplotlib.pyplot as plt
import scipy.integrate as si
import numpy as np
from tqdm import tqdm
from random import *

# %%
M_rocket = 2e5 # kg
DeltaV   = 2e3 #m/s

# %%
def M_Fuel(U):
    return M_rocket*np.expm1(DeltaV/U)

# %%
U_arr = np.linspace(5e3,1e5, 2000)
M_Fuel_arr = M_Fuel(U_arr)
plt.plot(U_arr, M_Fuel_arr, color="red")
plt.xlabel("Скорость вылета рабочего тела, м/с")
plt.ylabel("Необходимый запас топлива, кг")
plt.show()

# %%
n = 5
array = []
for i in range(n):
    for j in range(n):
        array.append((randint(-1000,1000)/100.0,randint(-1000,1000)/100.0 ))
for i in array:
    print(*i)
# Out:
# 0.44 -4.64
# 0.69 -6.07
# -4.87 -4.29
# 4.61 5.85
# -6.83 -2.44
# 5.3 -0.49
# 4.8 1.52
# 5.29 1.08
# 9.8 0.83
# 8.4 0.98
# -5.98 1.26
# -6.96 7.82
# 6.73 1.64
# -4.16 -5.99
# 4.71 -7.07
# 6.53 -1.15
# 0.13 3.03
# 8.01 2.53
# -0.67 -8.07
# 5.2 3.99
# 5.39 0.33
# 1.49 5.88
# -1.03 -7.85
# -2.28 -9.4
# -9.02 8.53

# %%
arr = np.array(array).reshape((n,n,2))
print(arr)
# Out:
# [[[ 0.44 -4.64]
#   [ 0.69 -6.07]
#   [-4.87 -4.29]
#   [ 4.61  5.85]
#   [-6.83 -2.44]]
#
#  [[ 5.3  -0.49]
#   [ 4.8   1.52]
#   [ 5.29  1.08]
#   [ 9.8   0.83]
#   [ 8.4   0.98]]
#
#  [[-5.98  1.26]
#   [-6.96  7.82]
#   [ 6.73  1.64]
#   [-4.16 -5.99]
#   [ 4.71 -7.07]]
#
#  [[ 6.53 -1.15]
#   [ 0.13  3.03]
#   [ 8.01  2.53]
#   [-0.67 -8.07]
#   [ 5.2   3.99]]
#
#  [[ 5.39  0.33]
#   [ 1.49  5.88]
#   [-1.03 -7.85]
#   [-2.28 -9.4 ]
#   [-9.02  8.53]]]

# %%
x, y = np.meshgrid(np.linspace(-5, 5, 10),  
                   np.linspace(-5, 5, 10)) 
  
# Directional vectors 
u = 1
v = 0
  
# Plotting Vector Field with QUIVER 
plt.quiver(x, y, u, v, color='blue') 
plt.title('Vector Field') 
  
# Setting x, y boundary limits 
#plt.xlim(-7, 7) 
#plt.ylim(-7, 7) 
  
# Show plot with grid 
plt.grid() 
plt.show()
